# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os, sys

import pandas as pd
from sklearn.linear_model import LinearRegression
from data_processing import *
from utils import generate_prediction
# Out:
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %% [markdown]
# ## Load dataset

# %%
DATA_DIR = './data'
train_data = os.path.join(DATA_DIR, 'train.csv')
test_data = os.path.join(DATA_DIR, 'test.csv')

train_df = pd.read_csv(train_data)
test_df = pd.read_csv(test_data)

train_final = os.path.join(DATA_DIR, 'train_with_mrt_mall_school.csv')
test_final = os.path.join(DATA_DIR, 'test_with_mrt_mall_school.csv')
train_final_df, test_final_df = pd.read_csv(train_final), pd.read_csv(test_final)
target = 'monthly_rent'
# train_df

# %% [markdown]
# ## Define simple feature and simple regression

# %%
features = ['floor_area_sqm',
                         'age',
                         'date',
                         'town_psqm']
cat_features = ['flat_model', 'flat_type']
target = 'monthly_rent'
out_df = generate_prediction(features, cat_features, train_df, test_df, target)
out_df.to_csv('my_pred.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# 60000 30000

# %%
features = ['floor_area_sqm',
                         'age',
                         'date',
                         'town_psqm']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
target = 'monthly_rent'
out_df = generate_prediction(features, cat_features, train_df, test_df, target)
out_df.to_csv('my_pred.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# 60000 30000

# %%
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
target = 'monthly_rent'

out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target)
out_df.to_csv('my_pred.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# 60000 30000

# %%
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name', 'nearest_mall_name', 'nearest_school_name']
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[LinearRegression()])
out_df.to_csv('my_pred.csv')
# Out:
# Pipeline(steps=[('linearregression', LinearRegression())])
# 60000 30000

# %%
out_df
# Out:
#          predicted
# id
# 0      3169.185911
# 1      2910.748411
# 2      3481.498411
# 3      2096.373411
# 4      2602.498411
# ...            ...
# 29995  2954.248411
# 29996  2843.170286
# 29997  2842.998411
# 29998  3320.060911
# 29999  3286.373411
#
# [30000 rows x 1 columns]

# %%
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[LinearRegression()])
out_df.to_csv('my_pred.csv')
# Out:
# Pipeline(steps=[('linearregression', LinearRegression())])
# 60000 30000

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.preprocessing import StandardScaler
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = []
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[StandardScaler(), MLPRegressor(random_state=1, max_iter=1000)])
out_df.to_csv('my_pred_mlp.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpregressor', MLPRegressor(max_iter=1000, random_state=1))])
# 60000 30000

# %%
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[StandardScaler(), MLPRegressor(random_state=1, max_iter=1000)])
out_df.to_csv('my_pred_mlp.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpregressor', MLPRegressor(max_iter=1000, random_state=1))])
# 60000 30000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
target = 'psqm'
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[StandardScaler(), MLPRegressor(random_state=1, max_iter=1000)])
out_df['predicted'] = train_final_df['floor_area_sqm'] * out_df['predicted']
out_df.to_csv('my_pred_mlp.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpregressor', MLPRegressor(max_iter=1000, random_state=1))])
# 60000 30000

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
target = 'monthly_rent'
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[StandardScaler(), MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(200,), learning_rate='adaptive', early_stopping=True)])
# out_df['predicted'] = train_final_df['floor_area_sqm'] * out_df['predicted']
# 482.78
out_df.to_csv('my_pred_mlp.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpregressor',
#                  MLPRegressor(early_stopping=True, hidden_layer_sizes=(200,),
#                               learning_rate='adaptive', max_iter=1000,
#                               random_state=1))])
# 60000 30000

# %%
out_df.to_csv('my_pred_mlp.csv')

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
features = ['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date']
cat_features = ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town']
target = 'monthly_rent'
out_df = generate_prediction(features, cat_features, train_final_df, test_final_df, target, pipelines=[StandardScaler(), MLPRegressor(random_state=1, max_iter=1000, hidden_layer_sizes=(200,), learning_rate='adaptive', 
                                                                                                                                      early_stopping=True,learning_rate_init=0.01, alpha=0.001)])
# out_df['predicted'] = train_final_df['floor_area_sqm'] * out_df['predicted']
out_df.to_csv('my_pred_mlp.csv')
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('mlpregressor',
#                  MLPRegressor(alpha=0.001, early_stopping=True,
#                               hidden_layer_sizes=(200,),
#                               learning_rate='adaptive', learning_rate_init=0.01,
#                               max_iter=1000, random_state=1))])
# 60000 30000
