# %%
# !pip install virtualenv # install virtual environment
# !virtualenv /content/notebooks/cs5228 # create virtual environment
# ! source /content/notebooks/cs5228/bin/activate && pip install pandas plotly scikit-learn # install required package

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
nb_path = '/content/notebooks'
try:
  os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
except:
  print('Already linked notebook')
sys.path.insert(0,nb_path)
# sys.path.append('/content/notebooks/cs5228/lib/python3.10/site-packages') # add to path
