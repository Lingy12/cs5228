# %%
# %load_ext autoreload
# %autoreload 2
import os, sys

# %%
import pandas as pd
import plotly
from utils import train_kfold
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import SGDRegressor

# %%
import pandas as pd
from datetime import datetime
import plotly.graph_objects as go
import plotly.express as px
from sklearn.cluster import KMeans
from data_processing import clean_data, process_data, min_max_norm, z_norm, generate_features, combined_encoding

DATA_DIR = './data'
train = os.path.join(DATA_DIR, 'train.csv')
test = os.path.join(DATA_DIR, 'test.csv')

train_final = os.path.join(DATA_DIR, 'train_with_mrt_mall_school.csv')

train_final_df = pd.read_csv(train_final)
train_df, test_df = pd.read_csv(train), pd.read_csv(test)

train_df_cleaned = clean_data(train_df)
train_df_cleaned = process_data(train_df_cleaned)
train_df_cleaned_final = clean_data(train_final_df)
train_df_cleaned_final = process_data(train_df_cleaned_final)
# test_df_cleaned = clean_data(test_df)
# test_df_cleaned = process_data(test_df_cleaned)
train_df_cleaned_final.columns
# Out:
# Index(['Unnamed: 0', 'list_id', 'rent_approval_date', 'town', 'block',
#        'street_name', 'flat_type', 'flat_model', 'floor_area_sqm',
#        'lease_commence_date', 'latitude', 'longitude', 'subzone',
#        'planning_area', 'region', 'monthly_rent', 'near_mrt_count',
#        'nearest_code', 'nearest_mrt_name', 'nearest_open_year',
#        'nearest_mrt_dist', 'near_mall_count', 'nearest_mall_name',
#        'nearest_mall_dist', 'near_school_count', 'nearest_school_name',
#        'nearest_school_dist', 'type_model', 'model_digit', 'type_digit',
#        'psqm', 'date', 'age'],
#       dtype='object')

# %% [markdown]
# ## K-Fold Ablation Study

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'date'], [],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 389.0359610494529, mae = 395.17963347120826, pcc = 0.6956399893897269, mape = 0.1611456974610853
# Overall evaluation
# fold: 1: train_mse = 388.51830462365103, mae = 397.25598247788815, pcc = 0.6827754807720356, mape = 0.16419645199356203
# Overall evaluation
# fold: 2: train_mse = 389.6365011696308, mae = 388.71002275477736, pcc = 0.7016625499460719, mape = 0.1583380212237277
# Overall evaluation
# fold: 3: train_mse = 389.1335671244501, mae = 392.50230368935775, pcc = 0.6974791425132512, mape = 0.16171841856714564
# Overall evaluation
# fold: 4: train_mse = 388.7766455846114, mae = 395.99912460052695, pcc = 0.6897129694603578, mape = 0.16367662270217792
# Overall evaluation
# fold: 5: train_mse = 388.6818930526627, mae = 396.40877650987557, pcc = 0.6911130531961208, mape = 0.1620875019653057
# Overall evaluation
# fold: 6: train_mse = 389.49200100939146, mae = 390.8772459753244, pcc = 0.7013997564485029, mape = 0.15882717975057234
# Overall evaluation
# fold: 7: train_mse = 390.26193017897623, mae = 382.4448671907225, pcc = 0.7032985489881614, mape = 0.1594523507303844
# Overall evaluation
# fold: 8: train_mse = 388.8624884355245, mae = 397.572346382389, pcc = 0.6911328636642117, mape = 0.16367967732533506
# Overall evaluation
# fold: 9: train_mse = 389.21485733879183, mae = 390.816085020668, pcc = 0.6967889788112706, mape = 0.1611265378087857
# Overall evaluation
# train_mae: average = 389.1614149567143, std_dev = 0.4946144727872824
# val_mape: average = 0.16142484595280818, std_dev = 0.0019671264982575962
# val_pcc: average = 0.695100333318971, std_dev = 0.006093624063961464
# val_mae: average = 392.7766388072738, std_dev = 4.508038909447446

# %%
train_kfold([
                        'floor_area_sqm',
                         ],[], 
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 541.8458947563109, mae = 546.7137771246031, pcc = 0.29077159854634615, mape = 0.21876821441487254
# Overall evaluation
# fold: 1: train_mse = 542.3100576196047, mae = 541.1296593426414, pcc = 0.30800886981122283, mape = 0.2183109842839026
# Overall evaluation
# fold: 2: train_mse = 543.2855278379635, mae = 534.1624841542721, pcc = 0.33118127824616983, mape = 0.21439289521862798
# Overall evaluation
# fold: 3: train_mse = 542.1095857007099, mae = 545.7597428897329, pcc = 0.31337414357439275, mape = 0.22200652717320427
# Overall evaluation
# fold: 4: train_mse = 542.0912737895671, mae = 544.432223647438, pcc = 0.291576678548652, mape = 0.21978261567200547
# Overall evaluation
# fold: 5: train_mse = 542.3864489103834, mae = 541.6937015458108, pcc = 0.3075647171139753, mape = 0.21716747645161438
# Overall evaluation
# fold: 6: train_mse = 542.0121924627988, mae = 546.7823746755577, pcc = 0.30510054261197356, mape = 0.21995065002306902
# Overall evaluation
# fold: 7: train_mse = 543.46094258073, mae = 534.627758271249, pcc = 0.3084532893784009, mape = 0.218414498691401
# Overall evaluation
# fold: 8: train_mse = 541.1992110636319, mae = 552.1436035249342, pcc = 0.2958719921023487, mape = 0.22303989059601273
# Overall evaluation
# fold: 9: train_mse = 542.9592102821587, mae = 536.3550141386143, pcc = 0.31310545165433473, mape = 0.21604767911026587
# Overall evaluation
# train_mae: average = 542.3660345003859, std_dev = 0.6556054665883508
# val_mape: average = 0.21878814316349757, std_dev = 0.0024616731279849444
# val_pcc: average = 0.3065008561587817, std_dev = 0.011367841256327805
# val_mae: average = 542.3800339314854, std_dev = 5.613237880969096

# %%
train_kfold(['floor_area_sqm',
                         'age',
                        ],[], 
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 538.5437810305704, mae = 543.494487074302, pcc = 0.3043747269145367, mape = 0.2177653808155779
# Overall evaluation
# fold: 1: train_mse = 539.0089466489701, mae = 537.7902849137882, pcc = 0.32183024792276155, mape = 0.21723842077222663
# Overall evaluation
# fold: 2: train_mse = 539.7537044829148, mae = 531.6987170358548, pcc = 0.3329951472310534, mape = 0.21330779095802885
# Overall evaluation
# fold: 3: train_mse = 538.7777672568435, mae = 542.7520028867299, pcc = 0.32038798983192623, mape = 0.22123231100258098
# Overall evaluation
# fold: 4: train_mse = 538.8374435870852, mae = 540.7465644531381, pcc = 0.30632650843058057, mape = 0.21854552217621062
# Overall evaluation
# fold: 5: train_mse = 539.1883639816045, mae = 537.6990820212267, pcc = 0.3228117259327877, mape = 0.2159122740467711
# Overall evaluation
# fold: 6: train_mse = 538.646248750889, mae = 543.8991381512009, pcc = 0.3154878801994866, mape = 0.2190779717241419
# Overall evaluation
# fold: 7: train_mse = 540.044469474058, mae = 531.906152833099, pcc = 0.31679217795605047, mape = 0.21735899359646896
# Overall evaluation
# fold: 8: train_mse = 537.9922293526871, mae = 548.2917316542113, pcc = 0.3098693658936603, mape = 0.22203020664167183
# Overall evaluation
# fold: 9: train_mse = 539.7673607740609, mae = 532.518816552102, pcc = 0.33234231445504536, mape = 0.2149077145440205
# Overall evaluation
# train_mae: average = 539.0560315339683, std_dev = 0.6063567054868448
# val_mape: average = 0.21773765862776995, std_dev = 0.0025386094717537696
# val_pcc: average = 0.3183218084767888, std_dev = 0.009321169891802294
# val_mae: average = 539.0796977575653, std_dev = 5.44422335285168

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'date'
                        ],[],
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 431.3015742116741, mae = 431.97102696540946, pcc = 0.626205330543946, mape = 0.1765417673313322
# Overall evaluation
# fold: 1: train_mse = 431.0104354157731, mae = 433.9594321530784, pcc = 0.6182639010617352, mape = 0.17976651408748293
# Overall evaluation
# fold: 2: train_mse = 432.04914765457903, mae = 424.79135014145277, pcc = 0.6366260278999677, mape = 0.17369319254720747
# Overall evaluation
# fold: 3: train_mse = 430.9280188188357, mae = 435.23731231448363, pcc = 0.6263565463317966, mape = 0.18054256639147442
# Overall evaluation
# fold: 4: train_mse = 430.7930296136701, mae = 436.275199616739, pcc = 0.6131766545279932, mape = 0.18050191207648106
# Overall evaluation
# fold: 5: train_mse = 431.0266555467041, mae = 433.5784102486687, pcc = 0.6254540365560094, mape = 0.17796506568185255
# Overall evaluation
# fold: 6: train_mse = 431.4778838256922, mae = 430.23880497190606, pcc = 0.6369521280993216, mape = 0.1758592882094424
# Overall evaluation
# fold: 7: train_mse = 432.31433231752374, mae = 422.22862256168185, pcc = 0.6314675058550637, mape = 0.17653498267841647
# Overall evaluation
# fold: 8: train_mse = 430.67110710368314, mae = 437.10025939609017, pcc = 0.6212989513709954, mape = 0.18066505740872846
# Overall evaluation
# fold: 9: train_mse = 431.63325918355287, mae = 428.0999582160866, pcc = 0.6295224527231712, mape = 0.1767468977604038
# Overall evaluation
# train_mae: average = 431.3205443691688, std_dev = 0.5174976763306575
# val_mape: average = 0.17788172441728217, std_dev = 0.002275584783644755
# val_pcc: average = 0.626532353497, std_dev = 0.0072054250806582185
# val_mae: average = 431.3480376585597, std_dev = 4.718133064318212

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'date',
                         'regional_psqm'
                        ],[],
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 403.50568641219695, mae = 407.5955946910259, pcc = 0.6779311774079291, mape = 0.16647432776861656
# Overall evaluation
# fold: 1: train_mse = 403.11098341513434, mae = 409.53767909163906, pcc = 0.665476777524109, mape = 0.16978518984037935
# Overall evaluation
# fold: 2: train_mse = 404.41704640128705, mae = 399.83067614720187, pcc = 0.6839964630693833, mape = 0.16335403978123908
# Overall evaluation
# fold: 3: train_mse = 403.86906552216146, mae = 403.9692851960127, pcc = 0.6811438643995026, mape = 0.16700505457067
# Overall evaluation
# fold: 4: train_mse = 403.0652484937329, mae = 411.3903371836681, pcc = 0.6644901307144654, mape = 0.17017748135813324
# Overall evaluation
# fold: 5: train_mse = 403.2335625220006, mae = 408.9265346936427, pcc = 0.6701449564913898, mape = 0.167372986976978
# Overall evaluation
# fold: 6: train_mse = 404.2044671578372, mae = 401.7353809417716, pcc = 0.684482024887463, mape = 0.16359424878277185
# Overall evaluation
# fold: 7: train_mse = 404.9730602589951, mae = 394.11782896271836, pcc = 0.6834145072658033, mape = 0.1648871323369773
# Overall evaluation
# fold: 8: train_mse = 403.527495376044, mae = 407.6001864977546, pcc = 0.6764335337781014, mape = 0.16833235276455624
# Overall evaluation
# fold: 9: train_mse = 404.14614931725635, mae = 401.07645596449447, pcc = 0.678828978237388, mape = 0.1660151740268012
# Overall evaluation
# train_mae: average = 403.8052764876646, std_dev = 0.59506769379781
# val_mape: average = 0.16669979882071226, std_dev = 0.0022241709015923127
# val_pcc: average = 0.6766342413775536, std_dev = 0.007090254987211934
# val_mae: average = 404.577995936993, std_dev = 5.107050879637956

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'date',
                         'town_psqm'
                        ],[],
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 389.6111692603314, mae = 395.65462699921477, pcc = 0.6942097801602104, mape = 0.16134505515872993
# Overall evaluation
# fold: 1: train_mse = 389.09266323134926, mae = 397.94083389624086, pcc = 0.6812960993583259, mape = 0.16445310839690827
# Overall evaluation
# fold: 2: train_mse = 390.14879241543537, mae = 389.29076478997496, pcc = 0.700553841205571, mape = 0.1585599921590336
# Overall evaluation
# fold: 3: train_mse = 389.649585462079, mae = 393.7933140531072, pcc = 0.6954337751582249, mape = 0.16224985496184938
# Overall evaluation
# fold: 4: train_mse = 389.34734305661897, mae = 396.3316457368797, pcc = 0.6891567330335119, mape = 0.16383569632653425
# Overall evaluation
# fold: 5: train_mse = 389.2300476642877, mae = 396.9649487004457, pcc = 0.6906689062197681, mape = 0.16235316170109176
# Overall evaluation
# fold: 6: train_mse = 390.0136443415557, mae = 392.0082845305022, pcc = 0.7000656034192502, mape = 0.15932603582950977
# Overall evaluation
# fold: 7: train_mse = 390.75979872681995, mae = 383.3368241174168, pcc = 0.7019056949537191, mape = 0.15977218527386852
# Overall evaluation
# fold: 8: train_mse = 389.3925967673544, mae = 398.8775866110255, pcc = 0.6891038890622241, mape = 0.16418114101823036
# Overall evaluation
# fold: 9: train_mse = 389.7251753573477, mae = 391.7359546951694, pcc = 0.6956407235979997, mape = 0.16140955655912917
# Overall evaluation
# train_mae: average = 389.69708162831796, std_dev = 0.4735523960125688
# val_mape: average = 0.1617485787384885, std_dev = 0.0019602141495315343
# val_pcc: average = 0.6938035046168805, std_dev = 0.00605445616953126
# val_mae: average = 393.5934784129977, std_dev = 4.468215247552316

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'date',
                         'town_psqm', 
                         'regional_psqm'
                        ],[],
                        train_df_cleaned, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 389.0359610494529, mae = 395.17963347120826, pcc = 0.6956399893897269, mape = 0.1611456974610853
# Overall evaluation
# fold: 1: train_mse = 388.5183046236509, mae = 397.25598247788815, pcc = 0.6827754807720358, mape = 0.16419645199356206
# Overall evaluation
# fold: 2: train_mse = 389.6365011696308, mae = 388.7100227547773, pcc = 0.7016625499460718, mape = 0.1583380212237277
# Overall evaluation
# fold: 3: train_mse = 389.1335671244501, mae = 392.5023036893577, pcc = 0.6974791425132513, mape = 0.16171841856714564
# Overall evaluation
# fold: 4: train_mse = 388.7766455846114, mae = 395.9991246005269, pcc = 0.6897129694603578, mape = 0.16367662270217792
# Overall evaluation
# fold: 5: train_mse = 388.6818930526627, mae = 396.40877650987557, pcc = 0.6911130531961209, mape = 0.1620875019653057
# Overall evaluation
# fold: 6: train_mse = 389.49200100939146, mae = 390.8772459753244, pcc = 0.7013997564485029, mape = 0.1588271797505723
# Overall evaluation
# fold: 7: train_mse = 390.26193017897623, mae = 382.44486719072245, pcc = 0.7032985489881612, mape = 0.1594523507303844
# Overall evaluation
# fold: 8: train_mse = 388.8624884355245, mae = 397.57234638238907, pcc = 0.6911328636642116, mape = 0.16367967732533506
# Overall evaluation
# fold: 9: train_mse = 389.21485733879183, mae = 390.816085020668, pcc = 0.6967889788112703, mape = 0.16112653780878572
# Overall evaluation
# train_mae: average = 389.1614149567143, std_dev = 0.4946144727872972
# val_mape: average = 0.16142484595280818, std_dev = 0.001967126498257603
# val_pcc: average = 0.695100333318971, std_dev = 0.006093624063961413
# val_mae: average = 392.7766388072738, std_dev = 4.508038909447467

# %% [markdown]
# ## Adding room feature

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'type_digit',
                         'date'],[],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 388.51196422663463, mae = 395.3654509991056, pcc = 0.6953162279323049, mape = 0.1611393377586167
# Overall evaluation
# fold: 1: train_mse = 388.10045461006416, mae = 396.6806311200239, pcc = 0.6834004828917402, mape = 0.16382017778885685
# Overall evaluation
# fold: 2: train_mse = 389.21494825994745, mae = 387.68314200910214, pcc = 0.7029973270033212, mape = 0.1578941892832271
# Overall evaluation
# fold: 3: train_mse = 388.65094267757354, mae = 392.0694291553384, pcc = 0.6980929131224192, mape = 0.16144698077281155
# Overall evaluation
# fold: 4: train_mse = 388.33703759254564, mae = 395.41198497969276, pcc = 0.690913509995516, mape = 0.16336939676605608
# Overall evaluation
# fold: 5: train_mse = 388.2435589504842, mae = 395.7345524818797, pcc = 0.6918226929320255, mape = 0.16176283669935565
# Overall evaluation
# fold: 6: train_mse = 389.04717878960395, mae = 390.2181504173703, pcc = 0.7028883767692976, mape = 0.15849816553575452
# Overall evaluation
# fold: 7: train_mse = 389.84761994174346, mae = 381.55548381379947, pcc = 0.7047294508783043, mape = 0.15903044712611752
# Overall evaluation
# fold: 8: train_mse = 388.40620475411816, mae = 397.2093121327398, pcc = 0.6922919785617742, mape = 0.16347860600081934
# Overall evaluation
# fold: 9: train_mse = 388.74119029578657, mae = 390.6928073811227, pcc = 0.6971890134398768, mape = 0.16099151391680924
# Overall evaluation
# train_mae: average = 388.71011000985015, std_dev = 0.5026952760360189
# val_mape: average = 0.16114316516484245, std_dev = 0.002002287240694261
# val_pcc: average = 0.6959641973526579, std_dev = 0.0062823874907607345
# val_mae: average = 392.26209444901747, std_dev = 4.667813534278032

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'type_digit',
                         'model_digit',
                         'date'],[],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 388.0216356231622, mae = 395.0644194429532, pcc = 0.6964452965056492, mape = 0.16112208595120697
# Overall evaluation
# fold: 1: train_mse = 387.6106335181086, mae = 396.2782143603687, pcc = 0.6837822259141352, mape = 0.16369053171841377
# Overall evaluation
# fold: 2: train_mse = 388.7590568774794, mae = 387.23283110687044, pcc = 0.70397353789961, mape = 0.15782073387148787
# Overall evaluation
# fold: 3: train_mse = 388.2177405387326, mae = 391.20758827764945, pcc = 0.6995723522693231, mape = 0.1610676883798537
# Overall evaluation
# fold: 4: train_mse = 387.8392732592868, mae = 394.9856328484481, pcc = 0.6917504481774313, mape = 0.1632396156608469
# Overall evaluation
# fold: 5: train_mse = 387.7799959226438, mae = 395.20972513480996, pcc = 0.6920609704955488, mape = 0.16149413209403407
# Overall evaluation
# fold: 6: train_mse = 388.52870321010977, mae = 389.9931172766735, pcc = 0.7035317952869551, mape = 0.15843564567722537
# Overall evaluation
# fold: 7: train_mse = 389.3733962456249, mae = 381.1396521797128, pcc = 0.705296336048136, mape = 0.1589239180658634
# Overall evaluation
# fold: 8: train_mse = 387.93465283909654, mae = 396.65825990852744, pcc = 0.6938687411250566, mape = 0.16335859317106874
# Overall evaluation
# fold: 9: train_mse = 388.2499412356979, mae = 389.947574802046, pcc = 0.6989611253542203, mape = 0.1607097059420915
# Overall evaluation
# train_mae: average = 388.23150292699427, std_dev = 0.5046223017909836
# val_mape: average = 0.16098626505320923, std_dev = 0.001978827955220629
# val_pcc: average = 0.6969242829076066, std_dev = 0.006382031706913013
# val_mae: average = 391.7717015338059, std_dev = 4.66507561450451

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'date'], ['flat_type'],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 384.70981040029, mae = 391.13003383546555, pcc = 0.7043414183537517, mape = 0.15918800256700222
# Overall evaluation
# fold: 1: train_mse = 384.1800025648213, mae = 394.20819726836385, pcc = 0.6900953357108731, mape = 0.16256225559411994
# Overall evaluation
# fold: 2: train_mse = 385.3050708831994, mae = 385.1532765581805, pcc = 0.7090845778427705, mape = 0.15645121101043014
# Overall evaluation
# fold: 3: train_mse = 384.86931049931417, mae = 387.29051961865076, pcc = 0.7079350377351321, mape = 0.15905222825381074
# Overall evaluation
# fold: 4: train_mse = 384.649801001003, mae = 390.99724970395886, pcc = 0.7003833344553191, mape = 0.16111078403336826
# Overall evaluation
# fold: 5: train_mse = 384.49436868295237, mae = 391.15410514120214, pcc = 0.6991526895667445, mape = 0.1593837566103733
# Overall evaluation
# fold: 6: train_mse = 384.93739060390214, mae = 387.7099068450293, pcc = 0.7094568562388314, mape = 0.15720152278985078
# Overall evaluation
# fold: 7: train_mse = 385.91922875056395, mae = 377.84138955494996, pcc = 0.7143350552983609, mape = 0.15687921928460047
# Overall evaluation
# fold: 8: train_mse = 384.614381686128, mae = 393.4837460053866, pcc = 0.6999349998424634, mape = 0.16138909551836178
# Overall evaluation
# fold: 9: train_mse = 384.8982726539623, mae = 386.71658856464137, pcc = 0.7070730469151632, mape = 0.15876310096793322
# Overall evaluation
# train_mae: average = 384.8577637726136, std_dev = 0.45284611955722515
# val_mape: average = 0.15919811766298508, std_dev = 0.0019217274765178061
# val_pcc: average = 0.7041792351959411, std_dev = 0.00658488903855268
# val_mae: average = 388.56850130958287, std_dev = 4.5568202171724055

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'date'], ['flat_model'],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 386.0669205797925, mae = 391.3763163689437, pcc = 0.703292801061374, mape = 0.15980218975229782
# Overall evaluation
# fold: 1: train_mse = 385.5284475611984, mae = 393.70326576808793, pcc = 0.688401423151055, mape = 0.16264955270152712
# Overall evaluation
# fold: 2: train_mse = 386.45025337318987, mae = 387.1284462859319, pcc = 0.706089121582732, mape = 0.15749413741208396
# Overall evaluation
# fold: 3: train_mse = 386.08462039524323, mae = 389.134513597016, pcc = 0.7041219029513802, mape = 0.15998359386225808
# Overall evaluation
# fold: 4: train_mse = 385.78886430582133, mae = 392.88561382847683, pcc = 0.6961030525460848, mape = 0.16233370805412484
# Overall evaluation
# fold: 5: train_mse = 385.4491130251977, mae = 394.4380763710369, pcc = 0.6941857181996974, mape = 0.1609115445046792
# Overall evaluation
# fold: 6: train_mse = 386.31939637453297, mae = 387.8980845009337, pcc = 0.7070615611235062, mape = 0.15761947005792648
# Overall evaluation
# fold: 7: train_mse = 387.20733154021747, mae = 379.7961026149039, pcc = 0.7088414595292305, mape = 0.15835952457055832
# Overall evaluation
# fold: 8: train_mse = 385.85109952572, mae = 394.2096673270526, pcc = 0.69761057796269, mape = 0.16225297918841122
# Overall evaluation
# fold: 9: train_mse = 386.24531789308105, mae = 387.0569225241191, pcc = 0.7051371925954371, mape = 0.15947933959272095
# Overall evaluation
# train_mae: average = 386.0991364573994, std_dev = 0.48254728870658414
# val_mape: average = 0.1600886039696588, std_dev = 0.0018232542290496964
# val_pcc: average = 0.7010844810703187, std_dev = 0.0062992477906230766
# val_mae: average = 389.76270091865024, std_dev = 4.324165430340056

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'date'], ['flat_type', 'flat_model'],
                        train_df_cleaned, 'monthly_rent', 10, feature_norm='z_norm')
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 383.0667587192018, mae = 388.6843892068038, pcc = 0.708562786509876, mape = 0.15839695580328747
# Overall evaluation
# fold: 1: train_mse = 382.4943742583049, mae = 391.96978881597363, pcc = 0.6931025659110204, mape = 0.16162064673132118
# Overall evaluation
# fold: 2: train_mse = 383.5684556105735, mae = 383.7611263647682, pcc = 0.7124853419805354, mape = 0.15579696412359947
# Overall evaluation
# fold: 3: train_mse = 383.19468955314466, mae = 385.41692024775074, pcc = 0.7110817702533545, mape = 0.1582933498728308
# Overall evaluation
# fold: 4: train_mse = 382.8848965980819, mae = 389.5371586796562, pcc = 0.7040933348846743, mape = 0.16055856518774828
# Overall evaluation
# fold: 5: train_mse = 382.76328544840356, mae = 390.279554007883, pcc = 0.7011645478013065, mape = 0.15891367517927332
# Overall evaluation
# fold: 6: train_mse = 383.3562335979066, mae = 385.9211600419643, pcc = 0.7132828226116209, mape = 0.15652229038202142
# Overall evaluation
# fold: 7: train_mse = 384.3020795942081, mae = 376.3628341602217, pcc = 0.7171810167233375, mape = 0.15636227866695712
# Overall evaluation
# fold: 8: train_mse = 382.8753830915946, mae = 391.3529801402213, pcc = 0.7039641468762671, mape = 0.16058668478524787
# Overall evaluation
# fold: 9: train_mse = 383.2081039747341, mae = 384.7970864695079, pcc = 0.710520855610257, mape = 0.15800622615007226
# Overall evaluation
# train_mae: average = 383.1714260446154, std_dev = 0.47725505644126615
# val_mape: average = 0.15850576368823593, std_dev = 0.0018597284956716987
# val_pcc: average = 0.7075439189162249, std_dev = 0.006682913417562136
# val_mae: average = 386.8082998134751, std_dev = 4.421221864208818

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned, 'monthly_rent', 10, feature_norm='z_norm')
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 373.275601254539, mae = 380.05822427808556, pcc = 0.7238046671336541, mape = 0.15444163715221218
# Overall evaluation
# fold: 1: train_mse = 372.50755056332224, mae = 384.4478674672939, pcc = 0.7064722359987222, mape = 0.15824118452316668
# Overall evaluation
# fold: 2: train_mse = 373.78056602775126, mae = 374.62226739468423, pcc = 0.7273664039145719, mape = 0.15186053941904706
# Overall evaluation
# fold: 3: train_mse = 373.5750633637131, mae = 375.6237642212586, pcc = 0.725557071146188, mape = 0.1543017371721903
# Overall evaluation
# fold: 4: train_mse = 373.5550525605678, mae = 382.60296545218523, pcc = 0.7139813940323056, mape = 0.15736416466178316
# Overall evaluation
# fold: 5: train_mse = 372.8292945806418, mae = 382.4189815976123, pcc = 0.7134302128600836, mape = 0.15552071281418728
# Overall evaluation
# fold: 6: train_mse = 374.0679830597637, mae = 376.76059992179165, pcc = 0.725069319976362, mape = 0.15242388608398483
# Overall evaluation
# fold: 7: train_mse = 374.7877113679405, mae = 368.80639592770814, pcc = 0.728367220745876, mape = 0.15317639952653145
# Overall evaluation
# fold: 8: train_mse = 373.43654070431876, mae = 380.2460746240732, pcc = 0.7209532297049732, mape = 0.15571065358688127
# Overall evaluation
# fold: 9: train_mse = 374.50301287014014, mae = 377.77533932049465, pcc = 0.719284947522125, mape = 0.15496645537408327
# Overall evaluation
# train_mae: average = 373.63183763526985, std_dev = 0.662540159707287
# val_mape: average = 0.15480073703140676, std_dev = 0.001925934171590948
# val_pcc: average = 0.7204286703034861, std_dev = 0.006762376141160566
# val_mae: average = 378.3362480205188, std_dev = 4.400053523704418

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned, 'monthly_rent', 10)
# train_df_cleaned.columns
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 373.02917355181097, mae = 380.112950451437, pcc = 0.7237903850172346, mape = 0.15454289655539705
# Overall evaluation
# fold: 1: train_mse = 372.60384014919475, mae = 384.78211488592467, pcc = 0.7061671066160808, mape = 0.15833043804405011
# Overall evaluation
# fold: 2: train_mse = 373.5866006432268, mae = 374.8986988400675, pcc = 0.7271647443151675, mape = 0.15197119478538496
# Overall evaluation
# fold: 3: train_mse = 373.5832395629907, mae = 375.60053695704227, pcc = 0.7258080477712647, mape = 0.1543286809885852
# Overall evaluation
# fold: 4: train_mse = 372.8364061742443, mae = 381.9803490741284, pcc = 0.7152171627752181, mape = 0.15707606111169578
# Overall evaluation
# fold: 5: train_mse = 373.3029303937788, mae = 382.75377254746513, pcc = 0.7125891601701586, mape = 0.15572183060079522
# Overall evaluation
# fold: 6: train_mse = 374.1008348645751, mae = 377.01711912087467, pcc = 0.7256253974632241, mape = 0.1525582864702218
# Overall evaluation
# fold: 7: train_mse = 374.4193535726916, mae = 368.03996340406707, pcc = 0.7290327957253084, mape = 0.1527614929866871
# Overall evaluation
# fold: 8: train_mse = 373.3629996885837, mae = 380.9216167533766, pcc = 0.7207894859710129, mape = 0.155957229925511
# Overall evaluation
# fold: 9: train_mse = 373.45519411611934, mae = 377.1079449545691, pcc = 0.7203822810329422, mape = 0.15486059723508652
# Overall evaluation
# train_mae: average = 373.42805727172157, std_dev = 0.5190023440397846
# val_mape: average = 0.15481087087034145, std_dev = 0.0019315036401127699
# val_pcc: average = 0.7206566566857612, std_dev = 0.006915728153698031
# val_mae: average = 378.3215066988952, std_dev = 4.612428761492078

# %% [markdown]
# ## Using additional data

# %%
train_df_cleaned_final.columns
# Out:
# Index(['Unnamed: 0', 'list_id', 'rent_approval_date', 'town', 'block',
#        'street_name', 'flat_type', 'flat_model', 'floor_area_sqm',
#        'lease_commence_date', 'latitude', 'longitude', 'subzone',
#        'planning_area', 'region', 'monthly_rent', 'near_mrt_count',
#        'nearest_code', 'nearest_mrt_name', 'nearest_open_year',
#        'nearest_mrt_dist', 'near_mall_count', 'nearest_mall_name',
#        'nearest_mall_dist', 'near_school_count', 'nearest_school_name',
#        'nearest_school_dist', 'type_model', 'model_digit', 'type_digit',
#        'psqm', 'date', 'age'],
#       dtype='object')

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'near_mrt_count',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned_final, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 372.24207636515484, mae = 379.2911132192985, pcc = 0.7252237534662257, mape = 0.15409716006810245
# Overall evaluation
# fold: 1: train_mse = 371.59561318032513, mae = 384.01720789634186, pcc = 0.7077112758585576, mape = 0.1580771149282443
# Overall evaluation
# fold: 2: train_mse = 373.1755938507041, mae = 373.9609285726471, pcc = 0.728684864117235, mape = 0.15163165977077653
# Overall evaluation
# fold: 3: train_mse = 372.9005590470203, mae = 375.3099040944483, pcc = 0.7263891142289008, mape = 0.15419314386649818
# Overall evaluation
# fold: 4: train_mse = 371.80654128659654, mae = 381.96434161484154, pcc = 0.7157749608671963, mape = 0.15704026349701922
# Overall evaluation
# fold: 5: train_mse = 372.2342679646751, mae = 381.0699292411119, pcc = 0.7153171753724841, mape = 0.15479998640522907
# Overall evaluation
# fold: 6: train_mse = 372.9996821782446, mae = 374.94888863923535, pcc = 0.7277993615696235, mape = 0.15148448866147396
# Overall evaluation
# fold: 7: train_mse = 373.82385875393726, mae = 367.4868721877245, pcc = 0.7296130690074694, mape = 0.15251276885860598
# Overall evaluation
# fold: 8: train_mse = 373.1857926756514, mae = 380.08946856895056, pcc = 0.7224460305673119, mape = 0.15572249509145683
# Overall evaluation
# fold: 9: train_mse = 372.7159224390856, mae = 375.80917822902325, pcc = 0.7221627417887607, mape = 0.15420115490853636
# Overall evaluation
# train_mae: average = 372.6679907741395, std_dev = 0.6549673728831814
# val_mape: average = 0.1543760236055943, std_dev = 0.002056574712262949
# val_pcc: average = 0.7221122346843766, std_dev = 0.0067350878942243845
# val_mae: average = 377.39478322636234, std_dev = 4.603290025717373

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned_final, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 371.8240657742255, mae = 379.5505665885134, pcc = 0.7254199722386026, mape = 0.1542491191065247
# Overall evaluation
# fold: 1: train_mse = 371.24321832578465, mae = 383.2294884368889, pcc = 0.7085448204646383, mape = 0.15784750638872505
# Overall evaluation
# fold: 2: train_mse = 372.69348748391957, mae = 372.783742560245, pcc = 0.7304681746978833, mape = 0.15115915480101078
# Overall evaluation
# fold: 3: train_mse = 372.0634161755268, mae = 374.7523780401954, pcc = 0.7270986140367423, mape = 0.15376529635888847
# Overall evaluation
# fold: 4: train_mse = 371.4839926722193, mae = 381.37885349964904, pcc = 0.7159601556864306, mape = 0.15672720448329128
# Overall evaluation
# fold: 5: train_mse = 371.6252212343142, mae = 380.99913750197163, pcc = 0.7155245368272025, mape = 0.1548599951244815
# Overall evaluation
# fold: 6: train_mse = 372.2183856023431, mae = 374.65276004373834, pcc = 0.7284241622668791, mape = 0.15143931335715718
# Overall evaluation
# fold: 7: train_mse = 373.0552047768366, mae = 366.94029551038255, pcc = 0.7299693569281271, mape = 0.15220370383385395
# Overall evaluation
# fold: 8: train_mse = 372.02188047196125, mae = 379.43218020788004, pcc = 0.7229489750650041, mape = 0.15535137741757973
# Overall evaluation
# fold: 9: train_mse = 372.3060367313788, mae = 375.65292851111013, pcc = 0.7226331776504449, mape = 0.15425193201383255
# Overall evaluation
# train_mae: average = 372.05349092485096, std_dev = 0.5217292764827964
# val_mape: average = 0.1541854602885345, std_dev = 0.002061495097485138
# val_pcc: average = 0.7226991945861955, std_dev = 0.006856008346567493
# val_mae: average = 376.9372330900575, std_dev = 4.665896497480091

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name'],
                        train_df_cleaned_final, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 371.42467336011106, mae = 379.6280365100109, pcc = 0.7251060641077266, mape = 0.15414725309962735
# Overall evaluation
# fold: 1: train_mse = 370.607240577934, mae = 382.8296690320972, pcc = 0.7087288737834909, mape = 0.15762349611478593
# Overall evaluation
# fold: 2: train_mse = 372.07376571647063, mae = 372.47361035986546, pcc = 0.7307412900620304, mape = 0.15100029581071858
# Overall evaluation
# fold: 3: train_mse = 371.50593283345586, mae = 375.0061835988583, pcc = 0.7268978330187308, mape = 0.1538605546907308
# Overall evaluation
# fold: 4: train_mse = 371.2140944552509, mae = 381.01256241527255, pcc = 0.7164842514424368, mape = 0.15654707732322276
# Overall evaluation
# fold: 5: train_mse = 371.12114722940606, mae = 380.9672785130249, pcc = 0.7157038706025647, mape = 0.15494206143098024
# Overall evaluation
# fold: 6: train_mse = 371.58100143207895, mae = 374.8312140214246, pcc = 0.7281762476495524, mape = 0.15150878902205853
# Overall evaluation
# fold: 7: train_mse = 372.5754651013866, mae = 367.5767931389615, pcc = 0.7296210310561525, mape = 0.15239345590057848
# Overall evaluation
# fold: 8: train_mse = 371.4362704798263, mae = 379.06948670245373, pcc = 0.7236312786536058, mape = 0.15519175709498856
# Overall evaluation
# fold: 9: train_mse = 371.86643338728254, mae = 376.40120625880627, pcc = 0.7223533077694144, mape = 0.15447793010696004
# Overall evaluation
# train_mae: average = 371.5406024573203, std_dev = 0.5140275174084752
# val_mape: average = 0.15416926705946515, std_dev = 0.001992321893753651
# val_pcc: average = 0.7227444048145706, std_dev = 0.006706002785540542
# val_mae: average = 376.9796040550775, std_dev = 4.419646018077808

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name', 'nearest_mall_name'],
                        train_df_cleaned_final, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 370.7012446450447, mae = 378.3072937126085, pcc = 0.7263292338910101, mape = 0.15362008590944098
# Overall evaluation
# fold: 1: train_mse = 369.9970890506505, mae = 382.9030639791145, pcc = 0.708535514593035, mape = 0.1575567031563808
# Overall evaluation
# fold: 2: train_mse = 371.2016484417361, mae = 373.0291051756874, pcc = 0.7303280132805154, mape = 0.1513835194759514
# Overall evaluation
# fold: 3: train_mse = 370.81886539983526, mae = 375.02959549727615, pcc = 0.7265366063177886, mape = 0.15391559516999875
# Overall evaluation
# fold: 4: train_mse = 370.35813057112216, mae = 380.9185571343652, pcc = 0.7161033398614365, mape = 0.1566464940649213
# Overall evaluation
# fold: 5: train_mse = 370.37798308479853, mae = 380.96026611824476, pcc = 0.7154254140952764, mape = 0.15496810130732785
# Overall evaluation
# fold: 6: train_mse = 371.1924907573144, mae = 373.60795746355984, pcc = 0.7298319873002954, mape = 0.15090395599353565
# Overall evaluation
# fold: 7: train_mse = 371.8985603202263, mae = 367.5957594807033, pcc = 0.7296830694467926, mape = 0.15255280465832985
# Overall evaluation
# fold: 8: train_mse = 370.9707322595606, mae = 379.5909734608301, pcc = 0.723714513124932, mape = 0.1554764556143318
# Overall evaluation
# fold: 9: train_mse = 370.92613746793705, mae = 375.9642210070917, pcc = 0.7226828955718531, mape = 0.15436203483666766
# Overall evaluation
# train_mae: average = 370.8442881998226, std_dev = 0.5075206740873245
# val_mape: average = 0.1541385750186886, std_dev = 0.0020343927948334845
# val_pcc: average = 0.7229170587482935, std_dev = 0.00695221210395965
# val_mae: average = 376.79067930294815, std_dev = 4.410646221516623

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name', 'nearest_mall_name', 'nearest_school_name'],
                        train_df_cleaned_final, 'monthly_rent', 10)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])
# fold: 0: train_mse = 369.7729995994604, mae = 378.7443396371068, pcc = 0.7256399329254053, mape = 0.1537825035274644
# Overall evaluation
# fold: 1: train_mse = 368.94661406059396, mae = 382.6695217328863, pcc = 0.7096208973617857, mape = 0.15747868038387722
# Overall evaluation
# fold: 2: train_mse = 370.61124739784566, mae = 373.30527195547717, pcc = 0.72925006015179, mape = 0.1514686093702713
# Overall evaluation
# fold: 3: train_mse = 369.76648720729173, mae = 374.0627588537517, pcc = 0.7277034729267675, mape = 0.15340756776837944
# Overall evaluation
# fold: 4: train_mse = 369.8173589228039, mae = 381.78095480540134, pcc = 0.7145580219967672, mape = 0.1571791385795034
# Overall evaluation
# fold: 5: train_mse = 369.41425501562895, mae = 380.3243292659712, pcc = 0.7154258409976081, mape = 0.15449289089569113
# Overall evaluation
# fold: 6: train_mse = 370.44824258664704, mae = 373.7185126875667, pcc = 0.7296156302602965, mape = 0.1508731295762052
# Overall evaluation
# fold: 7: train_mse = 370.758906138256, mae = 368.4770733107595, pcc = 0.7287576695480574, mape = 0.1527724768600099
# Overall evaluation
# fold: 8: train_mse = 370.04474825121537, mae = 379.69483819847585, pcc = 0.7235512138116021, mape = 0.15571148384715078
# Overall evaluation
# fold: 9: train_mse = 370.23802532135113, mae = 154403032630.0745, pcc = 0.007343479537131529, mape = 51467677.57250595
# Overall evaluation
# train_mae: average = 369.9818884501094, std_dev = 0.5289608487472031
# val_mape: average = 5146767.895967243, std_dev = 15440303.225512901
# val_pcc: average = 0.6511466219517211, std_dev = 0.21470635470113403
# val_mae: average = 15440303602.285208, std_dev = 46320909675.929756

# %% [markdown]
# ## SGD

# %%
# try one-hot
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], 
                        #    ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name', 'nearest_mall_name', 'nearest_school_name'],
                           [],
                        train_df_cleaned_final, 'monthly_rent', 10, pipelines=[StandardScaler(), SGDRegressor(max_iter=1000, tol=1e-4)])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('sgdregressor', SGDRegressor(tol=0.0001))])
# fold: 0: train_mse = 386.21342606978754, mae = 390.9813070354733, pcc = 0.7048914715812133, mape = 0.15930098823889588
# Overall evaluation
# fold: 1: train_mse = 385.9670089361568, mae = 393.30218406316544, pcc = 0.6916522918442719, mape = 0.16245607004673626
# Overall evaluation
# fold: 2: train_mse = 386.8568079010567, mae = 385.5343864810293, pcc = 0.7094354432446595, mape = 0.15655350166503082
# Overall evaluation
# fold: 3: train_mse = 386.22366447182145, mae = 389.01976730461746, pcc = 0.7059548519959071, mape = 0.15942235686780495
# Overall evaluation
# fold: 4: train_mse = 385.53389832801014, mae = 392.6601912950091, pcc = 0.6968667942943676, mape = 0.16281296629733527
# Overall evaluation
# fold: 5: train_mse = 385.72970819353134, mae = 393.66352426891905, pcc = 0.6976606650266637, mape = 0.16059326404635985
# Overall evaluation
# fold: 6: train_mse = 386.3019322775096, mae = 387.06261771297574, pcc = 0.7087796236633721, mape = 0.15745162689211872
# Overall evaluation
# fold: 7: train_mse = 386.77329130569666, mae = 378.49679722471274, pcc = 0.7104415415112314, mape = 0.1578742024481563
# Overall evaluation
# fold: 8: train_mse = 386.52598258115836, mae = 393.2172499065099, pcc = 0.7007313942783702, mape = 0.16236697171935596
# Overall evaluation
# fold: 9: train_mse = 386.1168671097519, mae = 388.2523794965347, pcc = 0.7028735663367172, mape = 0.15992311934207035
# Overall evaluation
# train_mae: average = 386.2242587174481, std_dev = 0.3997038302643806
# val_mape: average = 0.15987550675638643, std_dev = 0.002084810838026779
# val_pcc: average = 0.7029287643776774, std_dev = 0.005852446816454601
# val_mae: average = 389.21904047889467, std_dev = 4.489162021539492

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], 
                           ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned_final, 'monthly_rent', 10, pipelines=[StandardScaler(), PCA(n_components=100), SGDRegressor(max_iter=1000, tol=1e-4)])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=100)),
#                 ('sgdregressor', SGDRegressor(tol=0.0001))])
# fold: 0: train_mse = 391.19716214063027, mae = 393.44971040650955, pcc = 0.7025234157704644, mape = 0.1607495576091999
# Overall evaluation
# fold: 1: train_mse = 392.65114175238836, mae = 404.1369601291688, pcc = 0.6765150626075904, mape = 0.1665247710245837
# Overall evaluation
# fold: 2: train_mse = 391.0534748654274, mae = 388.11495028438196, pcc = 0.7043759450439384, mape = 0.15801922364131452
# Overall evaluation
# fold: 3: train_mse = 392.74006814229904, mae = 394.9556544343943, pcc = 0.701073901763385, mape = 0.16224294492134791
# Overall evaluation
# fold: 4: train_mse = 390.26324218532227, mae = 396.4154015154566, pcc = 0.6919286470083862, mape = 0.16316056223669104
# Overall evaluation
# fold: 5: train_mse = 388.54718838563394, mae = 395.71505777794977, pcc = 0.692402932937661, mape = 0.1612451698257598
# Overall evaluation
# fold: 6: train_mse = 391.6278412248527, mae = 392.650116428741, pcc = 0.7026908359064171, mape = 0.15961351043587443
# Overall evaluation
# fold: 7: train_mse = 393.1353705846555, mae = 385.31818961601454, pcc = 0.701302044377537, mape = 0.16084006515815405
# Overall evaluation
# fold: 8: train_mse = 391.1358563014933, mae = 391.6111954287031, pcc = 0.7024564814804968, mape = 0.16105406992430524
# Overall evaluation
# fold: 9: train_mse = 389.8516368332865, mae = 393.327842881527, pcc = 0.6940709820935217, mape = 0.162191954839291
# Overall evaluation
# train_mae: average = 391.2202982415989, std_dev = 1.347620475970617
# val_mape: average = 0.16156418296165215, std_dev = 0.0021431864520795605
# val_pcc: average = 0.6969340248989399, std_dev = 0.008106760619374414
# val_mae: average = 393.5695078902847, std_dev = 4.784186635352301

# %% [markdown]
# ## SVM

# %%
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], 
                           ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town', 'nearest_mrt_name', 'nearest_mall_name', 'nearest_school_name'],
                        train_df_cleaned_final, 'monthly_rent', 10, pipelines=[StandardScaler(), PCA(n_components=10), svm.SVR()])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('pca', PCA(n_components=10)), ('svr', SVR())])

# %% [markdown]
# ## KNN regression

# %%
from sklearn.neighbors import KNeighborsRegressor
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], 
                           ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned_final, 'monthly_rent', 10, pipelines=[StandardScaler(), KNeighborsRegressor(n_neighbors=20)])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('kneighborsregressor', KNeighborsRegressor(n_neighbors=20))])
# fold: 0: train_mse = 367.00388888888887, mae = 385.5158333333333, pcc = 0.7082945829461729, mape = 0.1548390429984963
# Overall evaluation
# fold: 1: train_mse = 366.1689351851852, mae = 393.7629166666667, pcc = 0.6821422300783576, mape = 0.16003658632254372
# Overall evaluation
# fold: 2: train_mse = 366.8076388888889, mae = 384.93833333333333, pcc = 0.7003003252259062, mape = 0.1542234279778311
# Overall evaluation
# fold: 3: train_mse = 366.6937037037037, mae = 384.48583333333335, pcc = 0.7014605289144171, mape = 0.15630687189242473
# Overall evaluation
# fold: 4: train_mse = 365.7138425925926, mae = 395.845, pcc = 0.6835049578503087, mape = 0.16085592024581855
# Overall evaluation
# fold: 5: train_mse = 366.0164814814815, mae = 390.275, pcc = 0.6932564546146017, mape = 0.1566458152353602
# Overall evaluation
# fold: 6: train_mse = 366.77564814814815, mae = 385.9841666666667, pcc = 0.6983168286616184, mape = 0.1540849991562406
# Overall evaluation
# fold: 7: train_mse = 367.7257407407407, mae = 379.45416666666665, pcc = 0.7033468183929595, mape = 0.1555214546861462
# Overall evaluation
# fold: 8: train_mse = 366.8549537037037, mae = 388.4554166666667, pcc = 0.7084189861460027, mape = 0.15753789586524158
# Overall evaluation
# fold: 9: train_mse = 367.2600462962963, mae = 384.5995833333333, pcc = 0.7010173090357655, mape = 0.15580405547021103
# Overall evaluation
# train_mae: average = 366.702087962963, std_dev = 0.5675556081426598
# val_mape: average = 0.1565856069850314, std_dev = 0.0021853984522253907
# val_pcc: average = 0.6980059021866111, std_dev = 0.008681413803514098
# val_mae: average = 387.331625, std_dev = 4.606766224842248

# %% [markdown]
# ## Adaboost

# %%
from sklearn.ensemble import AdaBoostRegressor
train_kfold(['floor_area_sqm',
                         'age',
                         'town_psqm',
                         'regional_psqm',
                         'latitude',
                         'longitude',
                         'nearest_mrt_dist',
                         'nearest_mall_dist',
                         'near_mall_count',
                         'near_mrt_count',
                         'near_school_count', 
                         'nearest_school_dist',
                         'date'], 
                           ['flat_type', 'flat_model', 'region', 'subzone', 'planning_area', 'town'],
                        train_df_cleaned_final, 'monthly_rent', 10, pipelines=[StandardScaler(), AdaBoostRegressor(n_estimators=100)])
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('adaboostregressor', AdaBoostRegressor(n_estimators=100))])
# fold: 0: train_mse = 454.9204512250295, mae = 455.1901328582672, pcc = 0.6664481799435289, mape = 0.19175798840415398
# fold: 1: train_mse = 436.7226589303773, mae = 439.47156927587605, pcc = 0.6639333495397409, mape = 0.18426723192568548
# fold: 2: train_mse = 459.85211326250095, mae = 455.27339898371497, pcc = 0.6592539776425351, mape = 0.18967976131266384
# fold: 3: train_mse = 455.53830814205014, mae = 460.5000607117366, pcc = 0.6459721572284706, mape = 0.19494343762150537
# fold: 4: train_mse = 435.36191283900814, mae = 440.76700165683, pcc = 0.6610037206849746, mape = 0.18575851024717452
# fold: 5: train_mse = 427.23114775443923, mae = 429.0491010200023, pcc = 0.6825736593529284, mape = 0.1775088256348159
# fold: 6: train_mse = 471.5933372523363, mae = 480.24805207547354, pcc = 0.6402084873160572, mape = 0.20259165359189482
# fold: 7: train_mse = 455.6091873553121, mae = 446.3203054588351, pcc = 0.6640745317961148, mape = 0.19120605606755756
# fold: 8: train_mse = 425.8540497672524, mae = 431.70682503071083, pcc = 0.6890911091664641, mape = 0.17903253283008466
# fold: 9: train_mse = 477.76211257164346, mae = 475.5222376748606, pcc = 0.6332915947350743, mape = 0.20222899293729316
# Overall evaluation
# val_mae: average = 451.4048684746307, std_dev = 16.41586698661273
